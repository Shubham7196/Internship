# %% [markdown]
# # Customer Retension

# %% [markdown]
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.

# %%
#Importing Libraries

import numpy as np
import pandas as pd
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
pd.pandas.set_option("display.max_column",None)

# %%
df = pd.read_excel('customer_retention_dataset.xlsx')
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
#Checking the no. of rows and columns
df.shape
# Out:
# (269, 71)

# %%
#checking the null values
df.isnull()
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                    False                False
# 1                    False                False
# 2                    False                False
# 3                    False                False
# 4                    False                False
# ..                     ...                  ...
# 264                  False                False
# 265                  False                False
# 266                  False                False
# 267                  False                False
# 268                  False                False
#
#      3 Which city do you shop online from?  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 264                                  False
# ...

# %%
#Checking the null value
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#Checking the datatypes
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
df.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %%
df.describe(include='all')
# Out:
#        1Gender of respondent 2 How old are you?   \
# count                    269                 269
# unique                     2                   5
# top                   Female         31-40 years
# freq                     181                  81
# mean                     NaN                 NaN
# std                      NaN                 NaN
# min                      NaN                 NaN
# 25%                      NaN                 NaN
# 50%                      NaN                 NaN
# 75%                      NaN                 NaN
# max                      NaN                 NaN
#
#        3 Which city do you shop online from?  \
# count                                    269
# unique                                    11
# top                                    Delhi
# freq                                      58
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
#Checking the Numbers of the columns
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %% [markdown]
# #### EDA
# 1) Checking the missing values
#
# 2) Checking for numerical columns
#
# 3) Checking for the the distribution of numerical variable
#
# 4) Checking for categorial data

# %%
df.nunique()
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %% [markdown]
# # Univariate Analysis:

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style="darkgrid")

plt.subplot(1,2,1)
df['1Gender of respondent'].value_counts().plot.pie(autopct='%1.1f%%', shadow ='true')

plt.subplot(1,2,2)
sns.countplot(df['1Gender of respondent'], palette="Set1")
df['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style="darkgrid")

plt.subplot(1,2,1)
df['2 How old are you? '].value_counts().plot.pie(autopct='%1.1f%%', shadow ='true')

plt.subplot(1,2,2)
sns.countplot(df['2 How old are you? '], palette="Set1")
df['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
plt.figure(figsize=(25,10))
sns.set_theme(style="darkgrid")

plt.subplot(1,2,1)
df['3 Which city do you shop online from?'].value_counts().plot.pie(autopct='%1.1f%%', shadow='true')

plt.subplot(1,2,2)
sns.countplot(y = df['3 Which city do you shop online from?'],palette ="Set1")
df['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
plt.figure(figsize =(30,10))
sns.set_theme(style = "darkgrid")
sns.countplot(df['4 What is the Pin Code of where you shop online from?'], palette = "Set1")
df['4 What is the Pin Code of where you shop online from?'].value_counts()
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# 201306     7
# 110014     6
# 110018     6
# 201008     5
# 201009     5
# 201305     5
# 201312     5
# 244001     5
# 530068     5
# 201005     4
# 110009     4
# 110042     4
# 110039     4
# 110030     4
# 201304     4
# 122009     4
# 201303     4
# 560018     4
# 201001     4
# 560003     4
# 560002     4
# 560013     3
# 203001     2
# 203207     1
# 560001     1
# 203202     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style = "darkgrid")
plt.subplot(1,2,1)
(df['5 Since How Long You are Shopping Online ?']).value_counts().plot.pie(autopct = "%1.1f%%", shadow = 'true')
plt.subplot(1,2,2)
sns.countplot(df['5 Since How Long You are Shopping Online ?'], palette = "Set1")
df['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['6 How many times youa have made an online purchase in the past 1 year?'], hue = df['6 How many times you have made an online purchase in the past 1 year?'])
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['7 How do you access the internet while shopping on-line?'], hue = df['7 How do you access the internet while shopping on-line?'])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['8 Which device do you use to access the online shopping?'], hue=df['8 Which device do you use to access the online shopping?'])
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '],palette = "Set1" )
df['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '].value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        , dtype: int64

# %%
df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '], palette= "Set1")
# Out:
# <AxesSubplot:xlabel='10 What is the operating system (OS) of your device?\t\t\t\t                                          ', ylabel='count'>

# %%
df['11 What browser do you run on your device to access the website?\t\t\t                                                          '].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?\t\t\t                                                          , dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['11 What browser do you run on your device to access the website?\t\t\t                                                          '], hue = df['11 What browser do you run on your device to access the website?\t\t\t                                                          '] )
# Out:
# <AxesSubplot:xlabel='11 What browser do you run on your device to access the website?\t\t\t                                                          ', ylabel='count'>

# %%
df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '], hue = df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '])
# Out:
# <AxesSubplot:xlabel='12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ', ylabel='count'>

# %%
df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   , dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style="white", palette= "Set1")
sns.countplot(df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '])
# Out:
# <AxesSubplot:xlabel='13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ', ylabel='count'>

# %%
df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '])
# Out:
# <AxesSubplot:xlabel='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ', ylabel='count'>

# %%
df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   , dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '])
# Out:
# <AxesSubplot:xlabel='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ', ylabel='count'>

# %%
df['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '], hue = df['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '])
plt.legend(loc='upper left')

# %% [markdown]
# ## Consumer opinion on Website features

# %%
df['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['18 The content on the website must be easy to read and understand'], hue = df['18 The content on the website must be easy to read and understand'])
plt.legend(loc='upper left')

# %%
df['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts()
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['19 Information on similar product to the one highlighted  is important for product comparison'], hue = df['19 Information on similar product to the one highlighted  is important for product comparison'])
plt.legend(loc='upper right')

# %%
df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['20 Complete information on listed seller and product being offered is important for purchase decision.'] ,hue = df['20 Complete information on listed seller and product being offered is important for purchase decision.'])
plt.legend(loc='upper right')

# %%
print(df['21 All relevant information on listed products must be stated clearly'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['21 All relevant information on listed products must be stated clearly'],palette="Set1")
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='21 All relevant information on listed products must be stated clearly', ylabel='count'>

# %%
print(df['22 Ease of navigation in website'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['22 Ease of navigation in website'], palette= "Set1")
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='22 Ease of navigation in website', ylabel='count'>

# %%
print(df['23 Loading and processing speed'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['23 Loading and processing speed'], palette= "Set2")
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Indifferent (3)           12
# Strongly disagree (1)     12
# Name: 23 Loading and processing speed, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='23 Loading and processing speed', ylabel='count'>

# %%
print(df['24 User friendly Interface of the website'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['24 User friendly Interface of the website'], palette= "Set2")
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='24 User friendly Interface of the website', ylabel='count'>

# %%
print(df['25 Convenient Payment methods'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['25 Convenient Payment methods'], palette= 'inferno')
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='25 Convenient Payment methods', ylabel='count'>

# %%
print(df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'], palette= 'inferno')
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time', ylabel='count'>

# %%
print(df['27 Empathy (readiness to assist with queries) towards the customers'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['27 Empathy (readiness to assist with queries) towards the customers'], palette= "Paired")
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='27 Empathy (readiness to assist with queries) towards the customers', ylabel='count'>

# %%
print(df['28 Being able to guarantee the privacy of the customer'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['28 Being able to guarantee the privacy of the customer'], palette= "Paired")
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='28 Being able to guarantee the privacy of the customer', ylabel='count'>

# %%
print(df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'], palette= "magma")
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)', ylabel='count'>

# %%
print(df['30 Online shopping gives monetary benefit and discounts'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['30 Online shopping gives monetary benefit and discounts'], palette= "magma")
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='30 Online shopping gives monetary benefit and discounts', ylabel='count'>

# %%
print(df['31 Enjoyment is derived from shopping online'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['31 Enjoyment is derived from shopping online'], palette= "viridis")
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='31 Enjoyment is derived from shopping online', ylabel='count'>

# %%
print(df['32 Shopping online is convenient and flexible'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['32 Shopping online is convenient and flexible'], palette= "viridis")
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='32 Shopping online is convenient and flexible', ylabel='count'>

# %%
print(df['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['33 Return and replacement policy of the e-tailer is important for purchase decision'], palette= "Set1")
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='33 Return and replacement policy of the e-tailer is important for purchase decision', ylabel='count'>

# %%
print(df['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['34 Gaining access to loyalty programs is a benefit of shopping online'], palette= "Set1")
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='34 Gaining access to loyalty programs is a benefit of shopping online', ylabel='count'>

# %%
print(df['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['35 Displaying quality Information on the website improves satisfaction of customers'], palette= "Set2")
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='35 Displaying quality Information on the website improves satisfaction of customers', ylabel='count'>

# %%
print(df['36 User derive satisfaction while shopping on a good quality website or application'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['36 User derive satisfaction while shopping on a good quality website or application'], palette= "Set2")
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='36 User derive satisfaction while shopping on a good quality website or application', ylabel='count'>

# %%
print(df['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['37 Net Benefit derived from shopping online can lead to users satisfaction'], palette='inferno')
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='37 Net Benefit derived from shopping online can lead to users satisfaction', ylabel='count'>

# %%
print(df['38 User satisfaction cannot exist without trust'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['38 User satisfaction cannot exist without trust'], palette= 'inferno')
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='38 User satisfaction cannot exist without trust', ylabel='count'>

# %%
print(df['39 Offering a wide variety of listed product in several category'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['39 Offering a wide variety of listed product in several category'], palette= "Paired")
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='39 Offering a wide variety of listed product in several category', ylabel='count'>

# %%
print(df['40 Provision of complete and relevant product information'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['40 Provision of complete and relevant product information'], palette= "Paired")
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='40 Provision of complete and relevant product information', ylabel='count'>

# %%
print(df['41 Monetary savings'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['41 Monetary savings'], palette="rocket_r")
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='41 Monetary savings', ylabel='count'>

# %%
print(df['42 The Convenience of patronizing the online retailer'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['42 The Convenience of patronizing the online retailer'], palette= "rocket_r")
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='42 The Convenience of patronizing the online retailer', ylabel='count'>

# %%
print(df['43 Shopping on the website gives you the sense of adventure'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['43 Shopping on the website gives you the sense of adventure'], palette="crest")
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='43 Shopping on the website gives you the sense of adventure', ylabel='count'>

# %%
print(df['44 Shopping on your preferred e-tailer enhances your social status'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['44 Shopping on your preferred e-tailer enhances your social status'], palette= "crest")
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='44 Shopping on your preferred e-tailer enhances your social status', ylabel='count'>

# %%
print(df['45 You feel gratification shopping on your favorite e-tailer'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['45 You feel gratification shopping on your favorite e-tailer'], palette= "Set1")
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='45 You feel gratification shopping on your favorite e-tailer', ylabel='count'>

# %%
print(df['46 Shopping on the website helps you fulfill certain roles'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['46 Shopping on the website helps you fulfill certain roles'], palette= "Set1")
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='46 Shopping on the website helps you fulfill certain roles', ylabel='count'>

# %%
print(df['47 Getting value for money spent'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(df['47 Getting value for money spent'], palette= "Set2")
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='47 Getting value for money spent', ylabel='count'>

# %%
print(df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '], palette= "Set2")
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64
# ____________________________________________________________________________________________________
# ...

# %%
print(df['Easy to use website or application'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Easy to use website or application'], palette= 'inferno')
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Easy to use website or application'>

# %%
print(df['Visual appealing web-page layout'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Visual appealing web-page layout'], palette= 'inferno')
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Myntra.com                                                      15
# Amazon.in, Myntra.com                                           15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Visual appealing web-page layout'>

# %%
print(df['Wild variety of product on offer'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y= df['Wild variety of product on offer'], palette= "Paired")
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Myntra.com                                            15
# Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Wild variety of product on offer'>

# %%
print(df['Complete, relevant description information of products'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y =df['Complete, relevant description information of products'], palette= "Paired")
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64
# ____________________________________________________________________________________________________
# ...

# %%
print(df['Fast loading website speed of website and application'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y=df['Fast loading website speed of website and application'], palette= "crest")
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Fast loading website speed of website and application'>

# %%
print(df['Reliability of the website or application'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Reliability of the website or application'], palette= "crest")
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Reliability of the website or application'>

# %%
print(df['Quickness to complete purchase'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Quickness to complete purchase'], palette= "Set1")
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Quickness to complete purchase'>

# %%
print(df['Availability of several payment options'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y =df['Availability of several payment options'], palette= "Set1")
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64
# ____________________________________________________________________________________________________
# ...

# %%
print(df['Speedy order delivery '].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Speedy order delivery '], palette= "Set2")
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Speedy order delivery '>

# %%
print(df['Privacy of customers’ information'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Privacy of customers’ information'], palette= "Set2")
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Myntra.com                                                      15
# Amazon.in, Paytm.com                                            15
# Flipkart.com                                                    15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Privacy of customers’ information'>

# %%
print(df['Security of customer financial information'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Security of customer financial information'], palette= 'inferno')
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64
# ____________________________________________________________________________________________________
# ...

# %%
print(df['Perceived Trustworthiness'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Perceived Trustworthiness'], palette= "inferno")
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Perceived Trustworthiness'>

# %%
print(df['Presence of online assistance through multi-channel'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Presence of online assistance through multi-channel'], palette= "crest")
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Presence of online assistance through multi-channel'>

# %%
print(df['Longer time to get logged in (promotion, sales period)'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y= df['Longer time to get logged in (promotion, sales period)'], palette= "crest")
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Longer time to get logged in (promotion, sales period)'>

# %%
print(df['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Longer time in displaying graphics and photos (promotion, sales period)'], palette= "Set1")
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Longer time in displaying graphics and photos (promotion, sales period)'>

# %%
print(df['Late declaration of price (promotion, sales period)'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Late declaration of price (promotion, sales period)'], palette= "Set1")
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Amazon.in                  38
# Flipkart.com               38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Late declaration of price (promotion, sales period)'>

# %%
print(df['Longer page loading time (promotion, sales period)'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Longer page loading time (promotion, sales period)'], palette= "Set2")
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Longer page loading time (promotion, sales period)'>

# %%
print(df['Limited mode of payment on most products (promotion, sales period)'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Limited mode of payment on most products (promotion, sales period)'], palette= "Set2")
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Limited mode of payment on most products (promotion, sales period)'>

# %%
print(df['Longer delivery period'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Longer delivery period'], palette= "inferno")
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Myntra.com                 26
# Paytm.com, Snapdeal.com    26
# Name: Longer delivery period, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Longer delivery period'>

# %%
print(df['Change in website/Application design'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Change in website/Application design'], palette= "inferno")
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Change in website/Application design'>

# %%
print(df['Frequent disruption when moving from one page to another'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Frequent disruption when moving from one page to another'], palette= "inferno")
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Frequent disruption when moving from one page to another'>

# %%
print(df['Website is as efficient as before'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Website is as efficient as before'], palette= "crest")
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Website is as efficient as before'>

# %%
print(df['Which of the Indian online retailer would you recommend to a friend?'].value_counts())
print("_"*100)
plt.figure(figsize=(15,5))
sns.countplot(y = df['Which of the Indian online retailer would you recommend to a friend?'], palette= "crest")
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64
# ____________________________________________________________________________________________________
# <AxesSubplot:xlabel='count', ylabel='Which of the Indian online retailer would you recommend to a friend?'>

# %% [markdown]
# # Bivariate Analysis
# In this section we will check the relations between feature vs feature. For that we will check the relations between others

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='2 How old are you? ', hue="1Gender of respondent",data=df, palette= "inferno")
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# female individuals of the age group 21-30 are involved in online shopping most. Female individuals of all the age groups are highly active than the male individuals in case of online shopping.

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='3 Which city do you shop online from?', hue="1Gender of respondent", data=df ,palette= "inferno")
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# Female individuals of Greater Noida are highest active in case of online shopping. Female individuals of Bangalore are 3rd highest active in case of online shopping. Male individuals from Delhi are 2nd highest active in case of online shopping.

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='5 Since How Long You are Shopping Online ?', hue="1Gender of respondent", data=df , palette= "inferno")
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# #
# Female individuals who are doing online shopping or using the e-retail apps since 4 years and above are highest in count.

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Security of customer financial information', hue="1Gender of respondent",data=df, palette= "inferno")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Security of customer financial information'>

# %% [markdown]
# ##
# Highest count of female individuals prefer Amazon.in because of security of customer financial information.

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Perceived Trustworthiness', hue="1Gender of respondent",data=df,palette= "inferno")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Perceived Trustworthiness'>

# %% [markdown]
# Highest count of female individuals prefer Amazon.in because of perceived trustworthiness.

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Presence of online assistance through multi-channel', hue="1Gender of respondent",data=df,palette= "inferno")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Presence of online assistance through multi-channel'>

# %% [markdown]
# Highest count of female individuals prefer Amazon.in because of the presence of online assistance through multi-channel.

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Longer time to get logged in (promotion, sales period)', hue="1Gender of respondent",data=df, palette= "inferno")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Longer time to get logged in (promotion, sales period)'>

# %% [markdown]
# ##
# Highest count of female individuals think Amazon.in take longer time to get logged in (promotion, sales period).

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Website is as efficient as before', hue="1Gender of respondent",data=df, palette= "inferno")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Website is as efficient as before'>

# %% [markdown]
# #
# Highest count of female individuals think in Amazon.in is the Indian online retailer that they would recommend to a friend.

# %% [markdown]
# #
# # Relations between different variables with city the customers do shopping online from.

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Speedy order delivery ', hue="3 Which city do you shop online from?", data=df, palette='Set1')
plt.legend(loc='upper right')

# %% [markdown]
# ## In Delhi, Amazon.in, Flipkart.com do highest speedy order delivery.

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='5 Since How Long You are Shopping Online ?', hue="3 Which city do you shop online from?",data=df,palette='Set1')
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# #
# Highest count of people from Greater Noida are doing online shopping since 4 years and above.

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='7 How do you access the internet while shopping on-line?', hue="3 Which city do you shop online from?",data=df,palette='Set1')
plt.legend(loc='upper left')

# %% [markdown]
# #
# Highest count of people from Greater Noida and Bangalore use mobile internet while shopping online.

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ', hue="3 Which city do you shop online from?",data=df,palette='Set1')
plt.legend(loc='upper right')

# %% [markdown]
# #
# Highest count of people from Bangalore mostly do online shopping from Anazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal,com.

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Security of customer financial information', hue="3 Which city do you shop online from?",data=df,palette='Set1')
plt.legend(loc='upper right')

# %% [markdown]
# #
# Highest count of people from Greater Noida think Amazon.in, Paytm.com, Myntra.com take care the security of customer financial information.

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Privacy of customers’ information', hue="3 Which city do you shop online from?",data=df,palette='Set1')
plt.legend(loc='upper right')

# %% [markdown]
# #
# Highest count of people from Delhi think Amazon.in, Flipkart.com take care the privacy of customers’ information.

# %% [markdown]
# # Relations between Trust and online portals:

# %%
plt.figure(figsize=(15,5))
sns.lineplot(y='Which of the Indian online retailer would you recommend to a friend?',x='Perceived Trustworthiness',data=df)
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Depending upon perceived trustworthiness, Highest count people recommend Amazon.in, Myntra.com to their friends.

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Which of the Indian online retailer would you recommend to a friend?',hue='Reliability of the website or application',data=df,)
plt.legend(loc='upper left')

# %% [markdown]
# ## Depending upon reliability of the website or application, Highest count people recommend Amazon.in to their friends.

# %% [markdown]
# # Conclusion:
#
#   Online shopping is a form of e-commerce which provides customers, the ability to browse and buy huge range of goods and services from sellers over the internet using different web browsers or mobile applications. Online shopping is related to life styles now a days. When people unable to shop offline as it's time consuming and also tiresome for some people, it's convenient to shop online. Moreover, perks of online shopping include, people can get things online that they can not get in local markets or super markets. Moreover, most of the e-retail shops give huge discounts to their customers.
# Now, we all know there are so many websites or mobile applications are ongoing, but according to the customers, all of the online shops are not capable of providing great deals or services all the times. And for that customer churn happens. And we have analysed various things that maybe helpful to retain the customers.
#
#   Now, the provided dataset is about 269 customers from Delhi, Greater Noida, Noida, Bangalore, Karnal, Solan, Ghaziabad, Gurgaon, Merrut, Moradabad, Bulandshahr who are asked 71 types of questions regarding e-commerce retail sectors to understand their point of view and experience. and we have analysed all the data throughly and closely and for that we can also say that it also serves as a survey of popularity of phones, popularity of web browsers.
#  As per the analysis,
# 1. The most preferred website/applicatiom is Anazon.in .
# 2. The most involved gender, regarding online shopping is Female.
# 3. People mostly use smartphones to stop online.
# 4. To retain customers, websites should fix their bugs as sometimes during sale the applications get lagged.
# 5. The e-retailers should maintain their quality as people are always looking for better options.
#
#
# 6. The most preferred website/applicatiom is Anazon.in .
# 7. The most involved gender, regarding online shopping is Female.
# 10. The e-retailers should maintain their quality as people are always looking for better options.

# %% [markdown]
# # Thank You :)
